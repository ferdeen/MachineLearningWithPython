# %% [markdown]
# # Linear Regression
# When and How to use Linear Regression

# %% [markdown]
# 1. Data

# %%
import pandas as pd
import numpy as np

fish = pd.read_csv("fish.csv")
fish.head()

# %%
fish.describe()

# %% [markdown]
# # Correlation

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numeric_cols = fish.select_dtypes(include=[np.number]).columns
sns.heatmap(fish[numeric_cols].corr(), annot=True)

# %% [markdown]
# Load Data and Plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fish = pd.read_csv("fish.csv")

x_height = fish['Height']
x_width = fish['Width']
y_weight = fish['Weight']

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_height, x_width, y_weight,c='blue', marker='o', alpha=0.5)
ax.set_xlabel('Height')
ax.set_ylabel('Widtth')
ax.set_zlabel('Weight')

# %% [markdown]
# Predict and Plot

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

x = np.column_stack((x_height, x_width))
y = y_weight

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=42)

model = LinearRegression().fit(X_train, y_train)

y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_height, x_width, y_weight, c='blue', marker='o', alpha=0.5, label="training set")
ax.scatter(X_test[:,0], X_test[:,1], y_pred_test, c='magenta', marker='+', s=80, label="test set")
ax.set_xlabel('Height')
ax.set_ylabel('Width')
ax.set_zlabel('Weight')
ax.legend()

# %% [markdown]
# Predict New Value (unseen in dataset)

# %%
y_pred_new = model.predict([[10,8]])

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_height, x_width, y_weight, c='blue', marker='o', alpha=0.5, label="training set")
ax.scatter(10, 8, y_pred_new, c='green', marker='x', s=80, label="test set")
ax.set_xlabel('Height')
ax.set_ylabel('Width')
ax.set_zlabel('Weight')
ax.legend()

print("the fish with height 10 and width 8 has a weight of", y_pred_new[0])
# Out:
# the fish with height 10 and width 8 has a weight of 1068.1123260157344
